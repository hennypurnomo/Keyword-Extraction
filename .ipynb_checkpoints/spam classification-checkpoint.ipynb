# %%
import os
import numpy
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, f1_score

NEWLINE = '\n'

HAM = 'ham'
SPAM = 'spam'

SOURCES = [
    ('data/spam',        SPAM),
    ('data/easy_ham',    HAM),
    ('data/hard_ham',    HAM),
]
    
SOURCES_ALL = [
    ('data/spam',        SPAM),
    ('data/easy_ham',    HAM),
    ('data/hard_ham',    HAM),
    ('data/beck-s',      HAM),
    ('data/farmer-d',    HAM),
    ('data/kaminski-v',  HAM),
    ('data/kitchen-l',   HAM),
    ('data/lokay-m',     HAM),
    ('data/williams-w3', HAM),
    ('data/BG',          SPAM),
    ('data/GP',          SPAM),
    ('data/SH',          SPAM)
]

SKIP_FILES = {'cmds'}

# %%
def read_files(path):
    for root, dir_names, file_names in os.walk(path):
        for path in dir_names:
            read_files(os.path.join(root, path))
        for file_name in file_names:
            if file_name not in SKIP_FILES:
                file_path = os.path.join(root, file_name)
                if os.path.isfile(file_path):
                    past_header, lines = False, []
                    f = open(file_path, encoding="latin-1") # modified for Python 2.7 MP
                    for line in f:
                        if past_header:
                            lines.append(line)
                        elif line == NEWLINE:
                            past_header = True
                    f.close()
                    content = NEWLINE.join(lines)
                    yield file_path, content

# %%
def build_data_frame(path, classification):
    rows = []
    index = [] 
    # create list with text and classification
    for file_name, text in read_files(path):
        rows.append({'text': text, 'class': classification})
        index.append(file_name)

    data_frame = DataFrame(rows, index=index)
    return data_frame

# %%
data = DataFrame({'text': [], 'class': []})
for path, classification in SOURCES:
    data = data.append(build_data_frame(path, classification))
# reorder ham and spam, because it was originally come from the same folder
data = data.reindex(numpy.random.permutation(data.index))
print("after",data)
# Out:
# after                                                    class  \
# data/easy_ham\01245.eb8e87560f382001583084d77b0...   ham
# data/easy_ham\02269.ee87871a0b0364173f13977f058...   ham
# data/spam\00344.17882edad13c2c761e6d8d99eef5a346    spam
# data/easy_ham\01870.2c9f4adcd1eec7ae3607d76bbf9...   ham
# data/easy_ham\02468.3ac182b2833f74c850d4bcaf63f...   ham
# data/easy_ham\00425.0ba16e840d94d629f8a3881b4e0...   ham
# data/easy_ham\01046.f0371dba9ae76787d5541e73a09...   ham
# data/easy_ham\00666.9f288224f19ca69b2663b5b9a85...   ham
# data/easy_ham\02036.ab9f23457f950a124c5b78449cc...   ham
# data/easy_ham\00563.8c8efdf5034a0ba771e48494fd2...   ham
# data/easy_ham\00911.dcbdde154d9f25c1afe32f4b8f5...   ham
# data/easy_ham\02402.7f699b32ac5965e5086d82b4199...   ham
# data/easy_ham\00127.c1981aeb12ebd22536f12f0a044...   ham
# data/easy_ham\00575.c4b32c1dc29245ce6298f5abf2f...   ham
# data/easy_ham\01407.5388b24c7941469cb0164922cf6...   ham
# data/easy_ham\01438.3bdd05f78df18d1add2e9a5afd8...   ham
# data/easy_ham\00588.708ecb20113d4c80b91936cd1c8...   ham
# data/easy_ham\00794.ce4c417f911968e4be6ee1203db...   ham
# data/easy_ham\02104.aecac880ad87b5a3e10b11414fe...   ham
# data/easy_ham\00120.4de6f88fbcb22a39a0498f84d9c...   ham
# data/easy_ham\00738.5c6ce770da4cc06ebea777b8be3...   ham
# data/hard_ham\00060.bb5f0a4bb14bf8126f7024c538c...   ham
# data/easy_ham\00529.f267247f996b2eab55c6e18b63e...   ham
# data/easy_ham\00096.3517ca839b03cdf37c14ff9b366...   ham
# data/easy_ham\01401.70777d5f3e75c701de00d7df66e...   ham
# data/easy_ham\01614.005f290e71d13de44d3503c640d...   ham
# data/easy_ham\02217.480e180ae8976cf6457850fd1ec...   ham
# data/easy_ham\02407.204ec9176022e4c98300ba4f7c0...   ham
# data/easy_ham\01408.3967d7ac324000b3216b1bdadf3...   ham
# data/easy_ham\00370.0a2e3b397565840b5c4e46d5c57...   ham
# ...                                                  ...
# data/hard_ham\00199.a69d994a7a76f49be4f4e8b839a...   ham
# data/easy_ham\01480.1d6e92e72f85630b288a7120753...   ham
# data/easy_ham\00191.41a15d7d511bc977b0fcb93cd94...   ham
# data/spam\00149.c07359393107925a86798dd72d6a56b3    spam
# data/easy_ham\02447.5ecaa423bfa4ab050e5b9a0a34f...   ham
# data/easy_ham\00956.f566e64727b8f438aa73ee8d26e...   ham
# data/spam\00350.c2658f17a328efdf045b38ab38db472f    spam
# data/easy_ham\01181.a1a32438921904f88c7c78f1fea...   ham
# data/easy_ham\00418.93eb266673b3731d82ce305ce6f...   ham
# data/easy_ham\00674.6dcadfb64e1a333f826a1c7b5c7...   ham
# data/easy_ham\01652.864cc509960bb627696e6594303...   ham
# data/spam\00229.4c37dd3d98b8d6fb2694b6f83061ca5a    spam
# data/easy_ham\01834.e716d845b22e35a8b7192215a37...   ham
# data/easy_ham\02129.6b9fb6fade127a4657fb25ec86f...   ham
# data/easy_ham\01781.37ea8ceefdbde6881efe1460f4a...   ham
# data/easy_ham\00091.abb1965e279e4365f1ef31e4878...   ham
# data/easy_ham\00301.48ccf486575754a29b80e4eae2c...   ham
# data/easy_ham\00957.7a0420bc5e7ed1ce8333c98dc76...   ham
# data/easy_ham\00025.d685245bdc4444f44fa091e6620...   ham
# data/easy_ham\00331.ccd0a9edb0852f4811a401d5335...   ham
# data/easy_ham\00114.240461056916c0cdd555ba9d2bc...   ham
# data/easy_ham\01281.f5f822f148c91fb7bc87e782f37...   ham
# data/easy_ham\01922.87f1df03581a29cd517b8fd78fe...   ham
# data/easy_ham\01104.703f48a4a1fa8c0e7053fba2399...   ham
# data/easy_ham\00036.719795e8d4670c6d8095274b18b...   ham
# data/easy_ham\00365.b73623c2ea40e64854121432f02...   ham
# data/easy_ham\01366.f862e5456473e82837fc0a89c6a...   ham
# data/spam\00216.89c1ede0b81fb09f7334f47a5183410a    spam
# data/easy_ham\00427.49db73be9017efca7355ee80f17...   ham
# data/easy_ham\02088.17edeee5193df341ff427a8b9b2...   ham
#
#                                                                                                  text
# data/easy_ham\01245.eb8e87560f382001583084d77b0...  Once upon a time, Roi wrote :\n\n\n\n> The new...
# data/easy_ham\02269.ee87871a0b0364173f13977f058...  URL: http://www.newsisfree.com/click/-5,856154...
# data/spam\00344.17882edad13c2c761e6d8d99eef5a346    --------------103227703017104\n\nContent-Type:...
# data/easy_ham\01870.2c9f4adcd1eec7ae3607d76bbf9...  URL: http://scriptingnews.userland.com/backiss...
# data/easy_ham\02468.3ac182b2833f74c850d4bcaf63f...  One more congratulation from me, Tim. Why 'Ro'...
# data/easy_ham\00425.0ba16e840d94d629f8a3881b4e0...  \n\nThis just blew my mind:\n\nhttp://www.eart...
# data/easy_ham\01046.f0371dba9ae76787d5541e73a09...  Once upon a time, Daniel wrote :\n\n\n\n>  > A...
# data/easy_ham\00666.9f288224f19ca69b2663b5b9a85...  \n\nIn a message dated 9/19/2002 3:45:45 PM, d...
# data/easy_ham\02036.ab9f23457f950a124c5b78449cc...  URL: http://diveintomark.org/archives/2002/09/...
# data/easy_ham\00563.8c8efdf5034a0ba771e48494fd2...  i though this was all rather interesting, firs...
# data/easy_ham\00911.dcbdde154d9f25c1afe32f4b8f5...  They are legally required to do that.  I got a...
# data/easy_ham\02402.7f699b32ac5965e5086d82b4199...  URL: http://www.newsisfree.com/click/-2,867404...
# data/easy_ham\00127.c1981aeb12ebd22536f12f0a044...  Tom R:\n\n> http://www.cliktrik.com/people/fam...
# data/easy_ham\00575.c4b32c1dc29245ce6298f5abf2f...  On 12 Sep 2002, Gary Lawrence Murphy wrote:\n\...
# data/easy_ham\01407.5388b24c7941469cb0164922cf6...  If you need to store a database password, then...
# data/easy_ham\01438.3bdd05f78df18d1add2e9a5afd8...  I'm getting an error page from sourceforge.net...
# data/easy_ham\00588.708ecb20113d4c80b91936cd1c8...  the doctor wears many hats, including but not ...
# data/easy_ham\00794.ce4c417f911968e4be6ee1203db...  \n\nIn essence, hindsight justification.  The ...
# data/easy_ham\02104.aecac880ad87b5a3e10b11414fe...  URL: http://www.newsisfree.com/click/-2,841882...
# data/easy_ham\00120.4de6f88fbcb22a39a0498f84d9c...  > That always amazes me about 'regular' dreams...
# data/easy_ham\00738.5c6ce770da4cc06ebea777b8be3...  I love the absurd sense of humor it takes to b...
# data/hard_ham\00060.bb5f0a4bb14bf8126f7024c538c...  \n\n<html>\n\n<head>\n\n\t<title>CNET Shopper ...
# data/easy_ham\00529.f267247f996b2eab55c6e18b63e...  Here are numbers that come from a study of a c...
# data/easy_ham\00096.3517ca839b03cdf37c14ff9b366...  \n\n-----BEGIN PGP SIGNED MESSAGE-----\n\nHash...
# data/easy_ham\01401.70777d5f3e75c701de00d7df66e...  I recently installed Razor v2.14 and started u...
# data/easy_ham\01614.005f290e71d13de44d3503c640d...  I've been testing Razor, invoked from sendmail...
# data/easy_ham\02217.480e180ae8976cf6457850fd1ec...  URL: http://www.newsisfree.com/click/-3,848315...
# data/easy_ham\02407.204ec9176022e4c98300ba4f7c0...  URL: http://diveintomark.org/archives/2002/10/...
# data/easy_ham\01408.3967d7ac324000b3216b1bdadf3...  -----BEGIN PGP SIGNED MESSAGE-----\n\nHash: SH...
# data/easy_ham\00370.0a2e3b397565840b5c4e46d5c57...  \n\nWell Beberg, unless you're really into Ani...
# ...                                                                                               ...
# data/hard_ham\00199.a69d994a7a76f49be4f4e8b839a...  This is a multi-part message in MIME format.\n...
# data/easy_ham\01480.1d6e92e72f85630b288a7120753...  On Sun, 15 Sep 2002 the voices made Marc Perke...
# data/easy_ham\00191.41a15d7d511bc977b0fcb93cd94...  > Ultimately, there was a big\n\n> disagreemen...
# data/spam\00149.c07359393107925a86798dd72d6a56b3    <HTML><HEAD><TITLE>New Web Technology</TITLE>\...
# data/easy_ham\02447.5ecaa423bfa4ab050e5b9a0a34f...  Raymond L. Wallace, 83\n\nBigfoot Story Teller...
# data/easy_ham\00956.f566e64727b8f438aa73ee8d26e...  \n\nI may be wrong but I think a single select...
# data/spam\00350.c2658f17a328efdf045b38ab38db472f    <HTML>\n\n<HEAD>\n\n</HEAD>\n\n<BODY>\n\n<FONT...
# data/easy_ham\01181.a1a32438921904f88c7c78f1fea...  This is a multi-part message in MIME format.\n...
# data/easy_ham\00418.93eb266673b3731d82ce305ce6f...  \n\n--- begin forwarded text\n\n\n\n\n\nFrom: ...
# data/easy_ham\00674.6dcadfb64e1a333f826a1c7b5c7...  Gary Lawrence Murphy:\n\n>OK, but only if you ...
# data/easy_ham\01652.864cc509960bb627696e6594303...  \n\n    >> Dunno about the other tools, but Sp...
# data/spam\00229.4c37dd3d98b8d6fb2694b6f83061ca5a    Dear zzzzason.org,\n\n\n\nMy name is Andy Koh,...
# data/easy_ham\01834.e716d845b22e35a8b7192215a37...  URL: http://boingboing.net/#85483339\n\nDate: ...
# data/easy_ham\02129.6b9fb6fade127a4657fb25ec86f...  URL: http://www.newsisfree.com/click/-1,839012...
# data/easy_ham\01781.37ea8ceefdbde6881efe1460f4a...  use Perl Daily Headline Mailer\n\n\n\nThis Wee...
# data/easy_ham\00091.abb1965e279e4365f1ef31e4878...  Hi Dermot, if have a look at one of the dists....
# data/easy_ham\00301.48ccf486575754a29b80e4eae2c...  > From: fork-admin@xent.com [mailto:fork-admin...
# data/easy_ham\00957.7a0420bc5e7ed1ce8333c98dc76...      Date:        Tue, 27 Aug 2002 18:08:12 -07...
# data/easy_ham\00025.d685245bdc4444f44fa091e6620...  \n\n> On Thu, 22 Aug 2002, John P. Looney wrot...
# data/easy_ham\00331.ccd0a9edb0852f4811a401d5335...  This message was sent to you from http://www.i...
# data/easy_ham\00114.240461056916c0cdd555ba9d2bc...  --- In forteana@y..., "Webmaster" <webmaster@b...
# data/easy_ham\01281.f5f822f148c91fb7bc87e782f37...  Once upon a time, Ville wrote :\n\n\n\n> Any p...
# data/easy_ham\01922.87f1df03581a29cd517b8fd78fe...  URL: http://www.aaronsw.com/weblog/000615\n\nD...
# data/easy_ham\01104.703f48a4a1fa8c0e7053fba2399...  Once upon a time, dTd wrote :\n\n\n\n> \n\n> T...
# data/easy_ham\00036.719795e8d4670c6d8095274b18b...  Mark Twomey joked:\n\n>  >erm... it runs Solar...
# data/easy_ham\00365.b73623c2ea40e64854121432f02...  Gary's news service at teledyn.com has an arti...
# data/easy_ham\01366.f862e5456473e82837fc0a89c6a...  Hi, I'm trying to build SA under Digital Unix ...
# data/spam\00216.89c1ede0b81fb09f7334f47a5183410a    This is a multi-part message in MIME format.\n...
# data/easy_ham\00427.49db73be9017efca7355ee80f17...  Jim Whitehead wrote:\n\n\n\n>Great, this is ha...
# data/easy_ham\02088.17edeee5193df341ff427a8b9b2...  URL: http://diveintomark.org/archives/2002/10/...
#
# [3250 rows x 2 columns]

# %%
vectorizer =  CountVectorizer(ngram_range=(1, 2))
dataa = vectorizer.fit_transform(data['text'].values)
print(dataa)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python35\site-packages\scipy\sparse\csr.py in asindices(x)
#     243                 if idx_dtype != x.dtype:
# --> 244                     x = x.astype(idx_dtype)
#     245             except:
#
# ValueError: invalid literal for int() with base 10: 'text'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-4ed79a26f2a2> in <module>()
#       1 vectorizer =  CountVectorizer(ngram_range=(1, 2))
# ----> 2 dataa = vectorizer.fit_transform(data['text'].values)
#       3 print(dataa)
#
# ~\AppData\Roaming\Python\Python35\site-packages\scipy\sparse\csr.py in __getitem__(self, key)
#     333             row, col = self._index_to_arrays(row, col)
#     334
# --> 335         row = asindices(row)
#     336         col = asindices(col)
#     337         if row.shape != col.shape:
#
# ~\AppData\Roaming\Python\Python35\site-packages\scipy\sparse\csr.py in asindices(x)
#     244                     x = x.astype(idx_dtype)
#     245             except:
# --> 246                 raise IndexError('invalid index')
#     247             else:
#     248                 return x
#
# IndexError: invalid index

# %%
pipeline = Pipeline([
    ('count_vectorizer',   CountVectorizer(ngram_range=(1, 2))),
    ('classifier',         MultinomialNB())
])
# Out:
# Pipeline(memory=None,
#      steps=[('count_vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
k_fold = KFold(n=len(data), n_folds=6)
scores = []
confusion = numpy.array([[0, 0], [0, 0]])
for train_indices, test_indices in k_fold:
    train_text = data.iloc[train_indices]['text'].values
    train_y = data.iloc[train_indices]['class'].values.astype(str)

    test_text = data.iloc[test_indices]['text'].values
    test_y = data.iloc[test_indices]['class'].values.astype(str)

    pipeline.fit(train_text, train_y)
    predictions = pipeline.predict(test_text)

    confusion += confusion_matrix(test_y, predictions)
    score = f1_score(test_y, predictions, pos_label=SPAM)
    scores.append(score)

# %%
print('Total emails classified:', len(data))
print('Score:', sum(scores)/len(scores))
print('Confusion matrix:')
print(confusion)
